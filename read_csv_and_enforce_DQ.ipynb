# %%
# !pip install --upgrade --user -q google-cloud-aiplatform langchain faiss-cpu==1.7.4

# %%
import google.cloud.bigquery as bq
import langchain
from google.cloud import aiplatform
from langchain.llms import VertexAI
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.prompts import PromptTemplate
from langchain.schema import format_document

# Print LangChain and Vertex AI versions
print(f"LangChain version: {langchain.__version__}")
print(f"Vertex AI SDK version: {aiplatform.__version__}")
# Out:
# LangChain version: 0.1.20
# Vertex AI SDK version: 1.51.0

# %%
llm = VertexAI(model_name="gemini-pro", temperature=0)

llm("Hello Gemini!")
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `VertexAI` was deprecated in LangChain 0.0.12 and will be removed in 0.3.0. An updated version of the class exists in the langchain-google-vertexai package and should be used instead. To use it run `pip install -U langchain-google-vertexai` and import as `from langchain_google_vertexai import VertexAI`.
#   warn_deprecated(
# /home/jupyter/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# 'Hello! How can I assist you today?'

# %%
# Load the data
loader = CSVLoader(file_path="./data/test_faulty_data.csv",csv_args={
                'delimiter': ','})

data = loader.load()

# %%
print(data[7].page_content)
# Out:
# path: /data_exchange__erp_prod/raw/01_SAP_P10/0101/v1/2024/0101__product_master_main_prdha_other__mm__202403__part0002.csv
# product_id: 000000000000011871
# drop_id: D1
# launch_type_mp: REGLAUNCH
# season_type: SS
# price_point: 060
# shop_live_date_actual: 1985-01-29
# material_name: SQUIRREL
# category_segment_id: D
# category_segment_name: HOME
# product_group: 34
# product_group_name: HOME
# product_segment: DD
# product_segment_name: DECORATIVE
# item_group: 10
# item_group_name: DECORATIVE
# item_subgroup:
# item_subgroup_name:
# prdha_level4:
# prdha_level4_name:
# product_hierarchy: 3410
# length:
# width:
# height:
# material_status: 80
# base_unit_of_measure: STST
# net_weight: 28.36
# gross_weight: 66.0
# weight_unit: G
# article_number: 7662
# size: NR042000
# global_retirement_date: 2019-12-31
# designer: 0035
# theme: 0170
# collection_code: VG
# launch_date_ex_sfl: 1985-01-01
# saison: 1985SS
# product_default_variant: 11871
# product_description_en: The lively squirrel runs through the woods on its search for food. This one in faceted clear crystal with Jet crystal eyes and a smooth tail is already enjoying his acorn and watching you watch it!
# product_dimension_imperial_en: Size: 7/8 x 1 5/8 inches
# product_dimension_metric_en: Size: 2.2 x 4.2 cm
# product_ean_code: 9003140118711
# product_master_id: 11871
# product_name_en: Squirrel
# product_phone_model_en:
# product_upc_code: 768549000102
# product_variant_color_en:
# product_variant_size_en:
# catalog_id: swaCatalog
# Z020_STONECOL:
# Z020_COLLECTION_TYPE:
# Z020_COUNTRY_EXCL:
# Z020_LABEL_COLOR:
# Z020_LADAT_PLAN:
# Z020_PROD_FAM:
# Z020_PL: NATURE COLLECTIONS
# Z020_PST: CRYSTAL NATURE
# Z020_PT: NATURE COLLECTIONS
# Z020_SIZE:
# Z020_ADDITIONAL_STONECOL:
# Z020_MANDATORY_PRODUCT:
# Z020_GENDER:
# Z020_EXCLUSIVITY:
# Z020_PYRAMID:
# Z020_PILLAR:
# ca_gift_occasion:
# ca_inner_color:
# ca_inner_material:
# ca_kcp:
# ca_country_of_origin_iso: in->at|ru->at
# ca_material_composition:
# ca_metal_color:
# ca_metal_type:
# ca_outer_color:
# ca_outer_material:
# ca_shape:
# ca_general_shape:
# ca_consumer_color:
# ca_product_set: Hot picks Louise Pentland Something blue
# ca_product_sub_type:
# ca_product_type:
# ca_plating_type:
# ca_primary_stone_shape:
# ca_default_category:
# ca_facets_number:
# ca_fragile:
# ca_gross_weight_carton_gr: 66
# ca_net_weight_carton_gr: 28.36
# ca_product_weight_kg:
# ca_jewelry_height:
# ca_jewelry_width:
# ca_model_year:
# ca_number_boxes: 2
# ca_number_of_stones:
# ca_number_pieces_sku:
# ca_season_of_the_product:
# ca_sustainability_label:
# ca_motif:
# ca_stone_color:
# ca_stone_treatment_method:
# ca_stone_type:
# ca_are_batteries_included:
# ca_azo_pcp:
# ca_band_type:
# ca_band_width:
# ca_batteries_required:
# ca_battery_type:
# ca_battery_weight_in_grams:
# ca_book_pages:
# ca_calendar_type:
# ca_carton_height_mm:
# ca_carton_length_mm:
# ca_case_diameter_mm:
# ca_case_length_mm:
# ca_case_thickness:
# ca_case_width_mm:
# ca_cgb_b2b_dontshowin_aut:
# ca_chain_length:
# ca_chain_length_mm:
# ca_controlcode_brazil: 7013.91.10
# ca_controlcode_india:
# ca_country_of_origin:
# ca_dangerous_good:
# ca_depth_carton_mm:
# ca_designer:
# ca_dial_length_mm:
# ca_dial_width_mm:
# ca_dimension_code_hide:
# ca_drop_length:
# ca_etui:
# ca_how_is_the_lithium_battery_packaged:
# ca_material_strap:
# ca_maximum_lenght_mm:
# ca_maximum_water_pressure_resistance:
# ca_number_of_batteries_included:
# ca_opening_distance_mm: 126 80
# ca_pearl_dimensions_mm:
# ca_pen_line_width_mm:
# ca_pendant_diameter_mm:
# ca_pendant_length_mm:
# ca_pendant_width_mm:
# ca_product_account_limit:
# ca_product_depth_mm:
# ca_product_diameter_mm:
# ca_product_effective_length_mm:
# ca_product_height_mm:
# ca_product_inside_depth_mm:
# ca_product_inside_length_mm:
# ca_product_inside_width_mm:
# ca_product_width_mm:
# ca_products_inner_pack:
# ca_resizable:
# ca_straps_length:
# ca_straps_width:
# ca_usb_capacity:
# ca_watch_strap_length_mm:
# ca_watch_strap_width_mm:
# ca_watch_waterproof:
# ZZNFMAT:
# ZZPLMID:
# extraction_date: 15-03-2024

# %%
#NB we probably need to chunck the input since it is too large

# %%
#set up a chain to pass the document to the LLM 
# Use code generation model
llm = VertexAI(model_name="gemini-pro",temperature=1, max_output_tokens=4096)

# Define the chain
chain = (
    {
        "content": lambda docs: "\n\n".join(
            format_document(doc, PromptTemplate.from_template("{page_content}"))
            for doc in docs
        )
    }
    | PromptTemplate.from_template(
        """
        In the following document:
        \n\n{content}
        I want to know if there are columns that contain entries that have the following format NNN NN.
        If so, tell me the row and the columsn where these are located and add an explanation about what you found
        """
    )
    | llm
)

# Invoke the chain with the documents, and remove code backticks
result = chain.invoke(data[6:8]).strip("```")
print(result)
# Out:
# ## Analysis of Columns for Entries in the Format "NNN NN"
#
# I have analyzed the provided data and identified several columns that contain entries in the format "NNN NN". Here's a breakdown:
#
# **Column** | **Row(s)** | **Explanation**
# ---|---|---|
# `product_ean_code` | 1, 2 | This column contains product European Article Numbers (EANs), which are 13-digit codes in the format "NNN NNNNNNNNNNN". The first three digits (NNN) represent the GS1 prefix, which identifies the country of origin.
# `product_upc_code` | 1, 2 | This column contains product Universal Product Codes (UPCs), which are 12-digit codes in the format "NNNNNNNNNNNN". The first digit (N) represents the number system, and the next five digits (NNNNN) represent the manufacturer code.
# `ca_controlcode_brazil` | 2 | This column contains the Brazilian control code for the product, which is in the format "NNN.NN.NN.NN". The first three digits (NNN) represent the tax code, and the remaining digits (NN.NN.NN.NN) represent the product code.
# `ca_controlcode_india` | 2 | This column contains the Indian control code for the product, which is in the format "NNN NNNNNNN". The first three digits (NNN) represent the Harmonized System (HS) code, and the remaining digits (NNNNNNNN) represent the product code.
#
# **Additional Notes:**
#
# * The columns `article_number` and `size` also contain entries with numbers separated by spaces, but these do not follow the specific format "NNN NN".
# * The values in the `ca_opening_distance_mm` column appear to be in the format "NNN NN", but upon closer inspection, they are actually two separate measurements (e.g., "126 80") separated by a space.
#
# **Conclusion:**
#
# The `product_ean_code`, `product_upc_code`, `ca_controlcode_brazil`, and `ca_controlcode_india` columns contain entries in the format "NNN NN". These codes are used for product identification and tracking purposes.

# %%
#load data into pandas df 
import pandas as pd

df = pd.read_csv('./data/test_faulty_data.csv',delimiter = ',')

# %%
pd.set_option('display.max_columns', None)
df.head(11)
# Out:
#                                                  path  product_id drop_id  \
# 0   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11859     NaN
# 1   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11860     NaN
# 2   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11861     NaN
# 3   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11862     NaN
# 4   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11864      D1
# 5   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11866      D1
# 6   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11867      D1
# 7   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11871      D1
# 8   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11872      D1
# 9   /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11888      D2
# 10  /data_exchange__erp_prod/raw/01_SAP_P10/0101/v...       11889      D2
#
#    launch_type_mp season_type  price_point shop_live_date_actual  \
# 0             NaN         NaN           60            1984-01-01
# 1             NaN         NaN           70            1984-01-01
# 2             NaN         NaN           60            1984-01-01
# 3             NaN         NaN           70            1984-01-01
# 4       REGLAUNCH          SS          220            1985-01-29
# 5       PRELAUNCH          SS            0                   NaN
# 6       REGLAUNCH          SS          150            1985-01-29
# 7       REGLAUNCH          SS           60            1985-01-29
# 8       PRELAUNCH          SS            0            2000-01-01
# 9       REGLAUNCH         NaN           10                   NaN
# 10      REGLAUNCH         NaN           10                   NaN
#
#                                material_name category_segment_id  \
# 0                              QUEEN CRYSTAL                   D
# 1                        CHESS SET-QUEEN JET                   D
# 2                               KING CRYSTAL                   D
# 3                         CHESS SET-KING JET                   D
# 4                            BUNCH OF GRAPES                   D
# 5   WATERLILY CANDLEHOLDER                 N                   D
# 6                     WATERLILY CANDLEHOLDER                   D
# 7                                   SQUIRREL                   D
# 8                                      11872                   D
# 9       A 9400  NR101001  CRY  BBZ      M201                   C
# 10      A 9400  NR101001  CRY  BBZ      M202                   C
#
#    category_segment_name  product_group product_group_name product_segment  \
# 0                   HOME             34               HOME              DA
# 1                   HOME             34               HOME              DA
# 2                   HOME             34               HOME              DA
# 3                   HOME             34               HOME              DA
# 4                   HOME             34               HOME              DD
# 5                   HOME             34               HOME              DA
# 6                   HOME             34               HOME              DA
# 7                   HOME             34               HOME              DD
# 8                   HOME             20                CSM              DD
# 9            ACCESSORIES             59                BJB              CF
# 10           ACCESSORIES             59                BJB              CF
#
#    product_segment_name  item_group          item_group_name  item_subgroup  \
# 0            FUNCTIONAL          20               FUNCTIONAL            NaN
# 1            FUNCTIONAL          20               FUNCTIONAL            NaN
# 2            FUNCTIONAL          20               FUNCTIONAL            NaN
# 3            FUNCTIONAL          20               FUNCTIONAL            NaN
# 4            DECORATIVE          10               DECORATIVE            NaN
# 5            FUNCTIONAL          20               FUNCTIONAL            NaN
# 6            FUNCTIONAL          20               FUNCTIONAL            NaN
# 7            DECORATIVE          10               DECORATIVE            NaN
# 8            DECORATIVE          84  PACKAGING MATERIAL HOME           10.0
# 9     OTHER ACCESSORIES          10          PERSONALIZATION           10.0
# 10    OTHER ACCESSORIES          10          PERSONALIZATION           10.0
#
#    item_subgroup_name  prdha_level4  prdha_level4_name  product_hierarchy  \
# 0                 NaN           NaN                NaN               3420
# 1                 NaN           NaN                NaN               3420
# 2                 NaN           NaN                NaN               3420
# 3                 NaN           NaN                NaN               3420
# 4                 NaN           NaN                NaN               3410
# 5                 NaN           NaN                NaN               3420
# 6                 NaN           NaN                NaN               3420
# 7                 NaN           NaN                NaN               3410
# 8             OBJECTS           NaN                NaN             208410
# 9           KEY RINGS           NaN                NaN             591010
# 10          KEY RINGS           NaN                NaN             591010
#
#     length  width  height  material_status base_unit_of_measure  net_weight  \
# 0     82.0   82.0    62.0               80                 STST      23.780
# 1      NaN    NaN     NaN               80                 STST      25.258
# 2      NaN    NaN     NaN               80                 STST      29.260
# 3      NaN    NaN     NaN               80                 STST      28.757
# 4      NaN    NaN     NaN               80                 STST     337.000
# 5      NaN    NaN     NaN               71                 STST     161.000
# 6    125.0  120.0    81.0               80                 STST     132.000
# 7      NaN    NaN     NaN               80                 STST      28.360
# 8      NaN    NaN     NaN               80                 STST       0.000
# 9      NaN    NaN     NaN               80                 STST      12.326
# 10     NaN    NaN     NaN               80                 STST      12.326
#
#     gross_weight weight_unit  article_number      size global_retirement_date  \
# 0         71.300           G            7469  NR052000             2010-12-31
# 1         71.618           G            7469  NR052010             2019-12-31
# 2         75.500           G            7469  NR062000             2010-12-31
# 3         75.862           G            7469  NR062010             2019-12-31
# 4        603.000           G            7509  NR150070             2019-12-31
# 5        161.000           G            7600  NR124000             2020-08-31
# 6        272.000           G            7600  NR124000             2020-08-31
# 7         66.000           G            7662  NR042000             2019-12-31
# 8          0.000           G            7700  NR060060             2004-12-31
# 9         19.946           G            9400  NR101001             2004-04-30
# 10        19.946           G            9400  NR101001             2004-04-30
#
#     designer  theme collection_code launch_date_ex_sfl  saison  \
# 0         35    129              VG         1984-01-01     NaN
# 1         35    129              VG         1984-01-01     NaN
# 2         35    129              VG         1984-01-01     NaN
# 3         35    129              VG         1984-01-01     NaN
# 4        997    191              VG         1985-01-01  1985SS
# 5         35    191             NaN         2013-11-22  2014SS
# 6         35    191              VG         1985-01-01  1985SS
# 7         35    170              VG         1985-01-01  1985SS
# 8          0      0             NaN         2000-01-01  2000SS
# 9          0      0             NaN                NaN     NaN
# 10         0      0             NaN                NaN     NaN
#
#     product_default_variant  \
# 0                   11859.0
# 1                   11860.0
# 2                   11861.0
# 3                   11862.0
# 4                   11864.0
# 5                       NaN
# 6                   11867.0
# 7                   11871.0
# 8                       NaN
# 9                   11888.0
# 10                  11889.0
#
#                                product_description_en  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Faceted clear crystal Bunch of Grapes with gol...
# 5                                                 NaN
# 6   Small clear crystal candleholder in the shape ...
# 7   The lively squirrel runs through the woods on ...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#      product_dimension_imperial_en product_dimension_metric_en  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4       Size: 5 7/8 x 2 3/4 inches             Size: 15 x 7 cm
# 5                              NaN                         NaN
# 6   Size: 1 7/8 x 3 x 2 5/8 inches      Size: 5 x 7.8 x 6.8 cm
# 7         Size: 7/8 x 1 5/8 inches          Size: 2.2 x 4.2 cm
# 8                              NaN                         NaN
# 9                              NaN                         NaN
# 10                             NaN                         NaN
#
#     product_ean_code  product_master_id         product_name_en  \
# 0      9003140118599            11859.0                     NaN
# 1      9003140118605            11860.0                     NaN
# 2      9003140118612            11861.0                     NaN
# 3      9003140118629            11862.0                     NaN
# 4      9003140118643            11864.0         Bunch of Grapes
# 5      9003140118667                NaN                     NaN
# 6      9003140118674            11867.0  Waterlily Candleholder
# 7      9003140118711            11871.0                Squirrel
# 8      9003140118728                NaN                     NaN
# 9      9003140118889            11888.0                     NaN
# 10     9003140118896            11889.0                     NaN
#
#     product_phone_model_en  product_upc_code  product_variant_color_en  \
# 0                      NaN      7.685490e+11                       NaN
# 1                      NaN      7.685490e+11                       NaN
# 2                      NaN      7.685490e+11                       NaN
# 3                      NaN      7.685490e+11                       NaN
# 4                      NaN      7.685490e+11                       NaN
# 5                      NaN               NaN                       NaN
# 6                      NaN      7.685490e+11                       NaN
# 7                      NaN      7.685490e+11                       NaN
# 8                      NaN               NaN                       NaN
# 9                      NaN      7.685495e+11                       NaN
# 10                     NaN      7.685495e+11                       NaN
#
#     product_variant_size_en  catalog_id Z020_STONECOL Z020_COLLECTION_TYPE  \
# 0                       NaN  swaCatalog           NaN                  NaN
# 1                       NaN  swaCatalog           NaN                  NaN
# 2                       NaN  swaCatalog           NaN                  NaN
# 3                       NaN  swaCatalog           NaN                  NaN
# 4                       NaN  swaCatalog           NaN                  NaN
# 5                       NaN  swaCatalog           NaN                  NaN
# 6                       NaN  swaCatalog       CRYSTAL                   GC
# 7                       NaN  swaCatalog           NaN                  NaN
# 8                       NaN  swaCatalog           NaN                  NaN
# 9                       NaN  swaCatalog           NaN                  NaN
# 10                      NaN  swaCatalog           NaN                  NaN
#
#     Z020_COUNTRY_EXCL Z020_LABEL_COLOR Z020_LADAT_PLAN Z020_PROD_FAM  \
# 0                 NaN              NaN             NaN           NaN
# 1                 NaN              NaN             NaN           NaN
# 2                 NaN              NaN             NaN           NaN
# 3                 NaN              NaN             NaN           NaN
# 4                 NaN              NaN             NaN           NaN
# 5                 NaN              NaN             NaN           NaN
# 6                 NaN              CRY      01.01.1985     WATERLILY
# 7                 NaN              NaN             NaN           NaN
# 8                 NaN              NaN             NaN           NaN
# 9                 NaN              NaN             NaN           NaN
# 10                NaN              NaN             NaN           NaN
#
#                Z020_PL        Z020_PST             Z020_PT  Z020_SIZE  \
# 0         CELEBRATIONS      HOME DECOR        CELEBRATIONS        NaN
# 1         CELEBRATIONS      HOME DECOR        CELEBRATIONS        NaN
# 2         CELEBRATIONS      HOME DECOR        CELEBRATIONS        NaN
# 3         CELEBRATIONS      HOME DECOR        CELEBRATIONS        NaN
# 4   NATURE COLLECTIONS  CRYSTAL NATURE  NATURE COLLECTIONS        NaN
# 5                  NaN             NaN                 NaN        NaN
# 6         CELEBRATIONS      HOME DECOR        CELEBRATIONS        NaN
# 7   NATURE COLLECTIONS  CRYSTAL NATURE  NATURE COLLECTIONS        NaN
# 8                  NaN             NaN                 NaN        NaN
# 9                  NaN             NaN                 NaN        NaN
# 10                 NaN             NaN                 NaN        NaN
#
#     Z020_ADDITIONAL_STONECOL Z020_MANDATORY_PRODUCT  Z020_GENDER  \
# 0                        NaN                    NaN          NaN
# 1                        NaN                    NaN          NaN
# 2                        NaN                    NaN          NaN
# 3                        NaN                    NaN          NaN
# 4                        NaN                    NaN          NaN
# 5                        NaN                    NaN          NaN
# 6                        NaN                     NO          NaN
# 7                        NaN                    NaN          NaN
# 8                        NaN                    NaN          NaN
# 9                        NaN                    NaN          NaN
# 10                       NaN                    NaN          NaN
#
#     Z020_EXCLUSIVITY   Z020_PYRAMID        Z020_PILLAR  ca_gift_occasion  \
# 0                NaN            NaN                NaN               NaN
# 1                NaN            NaN                NaN               NaN
# 2                NaN            NaN                NaN               NaN
# 3                NaN            NaN                NaN               NaN
# 4                NaN            NaN                NaN               NaN
# 5                NaN            NaN                NaN               NaN
# 6                NaN  VOLUME DRIVER  SCIENCE OF FACETS               NaN
# 7                NaN            NaN                NaN               NaN
# 8                NaN            NaN                NaN               NaN
# 9                NaN            NaN                NaN               NaN
# 10               NaN            NaN                NaN               NaN
#
#     ca_inner_color  ca_inner_material  ca_kcp ca_country_of_origin_iso  \
# 0              NaN                NaN     NaN                   in->at
# 1              NaN                NaN     NaN                   in->at
# 2              NaN                NaN     NaN                   in->at
# 3              NaN                NaN     NaN                   in->at
# 4              NaN                NaN     NaN                   in->at
# 5              NaN                NaN     NaN                      NaN
# 6              NaN                NaN     NaN            in->xs|ru->at
# 7              NaN                NaN     NaN            in->at|ru->at
# 8              NaN                NaN     NaN                      NaN
# 9              NaN                NaN     NaN            in->cn|ru->cn
# 10             NaN                NaN     NaN            in->cn|ru->cn
#
#     ca_material_composition  ca_metal_color  ca_metal_type  ca_outer_color  \
# 0                       NaN             NaN            NaN             NaN
# 1                       NaN             NaN            NaN             NaN
# 2                       NaN             NaN            NaN             NaN
# 3                       NaN             NaN            NaN             NaN
# 4                       NaN             NaN            NaN             NaN
# 5                       NaN             NaN            NaN             NaN
# 6                       NaN             NaN            NaN             NaN
# 7                       NaN             NaN            NaN             NaN
# 8                       NaN             NaN            NaN             NaN
# 9                       NaN             NaN            NaN             NaN
# 10                      NaN             NaN            NaN             NaN
#
#     ca_outer_material  ca_shape  ca_general_shape ca_consumer_color  \
# 0                 NaN       NaN               NaN               NaN
# 1                 NaN       NaN               NaN               NaN
# 2                 NaN       NaN               NaN               NaN
# 3                 NaN       NaN               NaN               NaN
# 4                 NaN       NaN               NaN               NaN
# 5                 NaN       NaN               NaN               NaN
# 6                 NaN       NaN               NaN             White
# 7                 NaN       NaN               NaN               NaN
# 8                 NaN       NaN               NaN               NaN
# 9                 NaN       NaN               NaN               NaN
# 10                NaN       NaN               NaN               NaN
#
#                               ca_product_set  ca_product_sub_type  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# 5                                        NaN                  NaN
# 6                                        NaN                  NaN
# 7   Hot picks Louise Pentland Something blue                  NaN
# 8                                        NaN                  NaN
# 9                                        NaN                  NaN
# 10                                       NaN                  NaN
#
#    ca_product_type  ca_plating_type  ca_primary_stone_shape  \
# 0              NaN              NaN                     NaN
# 1              NaN              NaN                     NaN
# 2              NaN              NaN                     NaN
# 3              NaN              NaN                     NaN
# 4              NaN              NaN                     NaN
# 5              NaN              NaN                     NaN
# 6       Home Decor              NaN                     NaN
# 7              NaN              NaN                     NaN
# 8              NaN              NaN                     NaN
# 9              NaN              NaN                     NaN
# 10             NaN              NaN                     NaN
#
#     ca_default_category  ca_facets_number  ca_fragile  \
# 0                   NaN               NaN         NaN
# 1                   NaN               NaN         NaN
# 2                   NaN               NaN         NaN
# 3                   NaN               NaN         NaN
# 4                   NaN               NaN         NaN
# 5                   NaN               NaN         NaN
# 6                 405.0               NaN         NaN
# 7                   NaN               NaN         NaN
# 8                   NaN               NaN         NaN
# 9                   NaN               NaN         NaN
# 10                  NaN               NaN         NaN
#
#     ca_gross_weight_carton_gr  ca_net_weight_carton_gr  ca_product_weight_kg  \
# 0                      71.300                   23.780                   NaN
# 1                      71.618                   25.258                   NaN
# 2                      75.500                   29.260                   NaN
# 3                      75.862                   28.757                   NaN
# 4                     603.000                  337.000                   NaN
# 5                         NaN                      NaN                   NaN
# 6                     272.000                  132.000                   NaN
# 7                      66.000                   28.360                   NaN
# 8                         NaN                      NaN                   NaN
# 9                      19.946                   12.326                   NaN
# 10                     19.946                   12.326                   NaN
#
#     ca_jewelry_height ca_jewelry_width  ca_model_year  ca_number_boxes  \
# 0                 NaN              NaN            NaN              NaN
# 1                 NaN              NaN            NaN              NaN
# 2                 NaN              NaN            NaN              NaN
# 3                 NaN              NaN            NaN              NaN
# 4                 NaN              NaN            NaN              NaN
# 5                 NaN              NaN            NaN              NaN
# 6                 5.0              7,8         2020.0              NaN
# 7                 NaN              NaN            NaN              2.0
# 8                 NaN              NaN            NaN              NaN
# 9                 NaN              NaN            NaN              NaN
# 10                NaN              NaN            NaN              NaN
#
#     ca_number_of_stones  ca_number_pieces_sku ca_season_of_the_product  \
# 0                   NaN                   NaN                      NaN
# 1                   NaN                   NaN                      NaN
# 2                   NaN                   NaN                      NaN
# 3                   NaN                   NaN                      NaN
# 4                   NaN                   NaN                      NaN
# 5                   NaN                   NaN                      NaN
# 6                   NaN                   NaN                   2014FW
# 7                   NaN                   NaN                      NaN
# 8                   NaN                   NaN                      NaN
# 9                   NaN                   NaN                      NaN
# 10                  NaN                   NaN                      NaN
#
#     ca_sustainability_label ca_motif  ca_stone_color  \
# 0                       NaN      NaN             NaN
# 1                       NaN      NaN             NaN
# 2                       NaN      NaN             NaN
# 3                       NaN      NaN             NaN
# 4                       NaN      NaN             NaN
# 5                       NaN      NaN             NaN
# 6                       NaN   flower             NaN
# 7                       NaN      NaN             NaN
# 8                       NaN      NaN             NaN
# 9                       NaN      NaN             NaN
# 10                      NaN      NaN             NaN
#
#     ca_stone_treatment_method  ca_stone_type  ca_are_batteries_included  \
# 0                         NaN            NaN                        NaN
# 1                         NaN            NaN                        NaN
# 2                         NaN            NaN                        NaN
# 3                         NaN            NaN                        NaN
# 4                         NaN            NaN                        NaN
# 5                         NaN            NaN                        NaN
# 6                         NaN            NaN                        NaN
# 7                         NaN            NaN                        NaN
# 8                         NaN            NaN                        NaN
# 9                         NaN            NaN                        NaN
# 10                        NaN            NaN                        NaN
#
#     ca_azo_pcp  ca_band_type  ca_band_width  ca_batteries_required  \
# 0          NaN           NaN            NaN                    NaN
# 1          NaN           NaN            NaN                    NaN
# 2          NaN           NaN            NaN                    NaN
# 3          NaN           NaN            NaN                    NaN
# 4          NaN           NaN            NaN                    NaN
# 5          NaN           NaN            NaN                    NaN
# 6          NaN           NaN            NaN                    NaN
# 7          NaN           NaN            NaN                    NaN
# 8          NaN           NaN            NaN                    NaN
# 9          NaN           NaN            NaN                    NaN
# 10         NaN           NaN            NaN                    NaN
#
#     ca_battery_type  ca_battery_weight_in_grams  ca_book_pages  \
# 0               NaN                         NaN            NaN
# 1               NaN                         NaN            NaN
# 2               NaN                         NaN            NaN
# 3               NaN                         NaN            NaN
# 4               NaN                         NaN            NaN
# 5               NaN                         NaN            NaN
# 6               NaN                         NaN            NaN
# 7               NaN                         NaN            NaN
# 8               NaN                         NaN            NaN
# 9               NaN                         NaN            NaN
# 10              NaN                         NaN            NaN
#
#     ca_calendar_type  ca_carton_height_mm  ca_carton_length_mm  \
# 0                NaN                 62.0                 82.0
# 1                NaN                  NaN                  NaN
# 2                NaN                  NaN                  NaN
# 3                NaN                  NaN                  NaN
# 4                NaN                  NaN                  NaN
# 5                NaN                  NaN                  NaN
# 6                NaN                 81.0                125.0
# 7                NaN                  NaN                  NaN
# 8                NaN                  NaN                  NaN
# 9                NaN                  NaN                  NaN
# 10               NaN                  NaN                  NaN
#
#     ca_case_diameter_mm  ca_case_length_mm  ca_case_thickness  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# 5                   NaN                NaN                NaN
# 6                   NaN                NaN                NaN
# 7                   NaN                NaN                NaN
# 8                   NaN                NaN                NaN
# 9                   NaN                NaN                NaN
# 10                  NaN                NaN                NaN
#
#     ca_case_width_mm  ca_cgb_b2b_dontshowin_aut ca_chain_length  \
# 0                NaN                        NaN             NaN
# 1                NaN                        NaN             NaN
# 2                NaN                        NaN             NaN
# 3                NaN                        NaN             NaN
# 4                NaN                        NaN             NaN
# 5                NaN                        NaN             NaN
# 6                NaN                        NaN             6,8
# 7                NaN                        NaN             NaN
# 8                NaN                        NaN             NaN
# 9                NaN                        NaN             NaN
# 10               NaN                        NaN             NaN
#
#     ca_chain_length_mm ca_controlcode_brazil  ca_controlcode_india  \
# 0                  NaN                   NaN            70139100.0
# 1                  NaN                   NaN            70139100.0
# 2                  NaN                   NaN                   NaN
# 3                  NaN                   NaN            70139100.0
# 4                  NaN                   NaN                   NaN
# 5                  NaN                   NaN                   NaN
# 6                  NaN            7013.99.00            70139100.0
# 7                  NaN            7013.91.10                   NaN
# 8                  NaN                   NaN                   NaN
# 9                  NaN            7326.20.00                   NaN
# 10                 NaN            7326.20.00                   NaN
#
#    ca_country_of_origin  ca_dangerous_good  ca_depth_carton_mm  ca_designer  \
# 0                   NaN                NaN                82.0          NaN
# 1                   NaN                NaN                 NaN          NaN
# 2                   NaN                NaN                 NaN          NaN
# 3                   NaN                NaN                 NaN          NaN
# 4                   NaN                NaN                 NaN          NaN
# 5                   NaN                NaN                 NaN          NaN
# 6                Serbia                NaN               120.0  Max Schreck
# 7                   NaN                NaN                 NaN          NaN
# 8                   NaN                NaN                 NaN          NaN
# 9                   NaN                NaN                 NaN          NaN
# 10                  NaN                NaN                 NaN          NaN
#
#     ca_dial_length_mm  ca_dial_width_mm  ca_dimension_code_hide  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
# 5                 NaN               NaN                     NaN
# 6                 NaN               NaN                     NaN
# 7                 NaN               NaN                     NaN
# 8                 NaN               NaN                     NaN
# 9                 NaN               NaN                     NaN
# 10                NaN               NaN                     NaN
#
#     ca_drop_length  ca_etui  ca_how_is_the_lithium_battery_packaged  \
# 0              NaN      NaN                                     NaN
# 1              NaN      NaN                                     NaN
# 2              NaN      NaN                                     NaN
# 3              NaN      NaN                                     NaN
# 4              NaN      NaN                                     NaN
# 5              NaN      NaN                                     NaN
# 6              NaN      NaN                                     NaN
# 7              NaN      NaN                                     NaN
# 8              NaN      NaN                                     NaN
# 9              NaN      NaN                                     NaN
# 10             NaN      NaN                                     NaN
#
#     ca_material_strap  ca_maximum_lenght_mm  \
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
# 5                 NaN                   NaN
# 6                 NaN                   NaN
# 7                 NaN                   NaN
# 8                 NaN                   NaN
# 9                 NaN                   NaN
# 10                NaN                   NaN
#
#     ca_maximum_water_pressure_resistance  ca_number_of_batteries_included  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 5                                    NaN                              NaN
# 6                                    NaN                              NaN
# 7                                    NaN                              NaN
# 8                                    NaN                              NaN
# 9                                    NaN                              NaN
# 10                                   NaN                              NaN
#
#    ca_opening_distance_mm  ca_pearl_dimensions_mm  ca_pen_line_width_mm  \
# 0                     NaN                     NaN                   NaN
# 1                     NaN                     NaN                   NaN
# 2                     NaN                     NaN                   NaN
# 3                     NaN                     NaN                   NaN
# 4                     NaN                     NaN                   NaN
# 5                     NaN                     NaN                   NaN
# 6                     NaN                     NaN                   NaN
# 7                  126 80                     NaN                   NaN
# 8                     NaN                     NaN                   NaN
# 9                     NaN                     NaN                   NaN
# 10                    NaN                     NaN                   NaN
#
#     ca_pendant_diameter_mm  ca_pendant_length_mm  ca_pendant_width_mm  \
# 0                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 2                      NaN                   NaN                  NaN
# 3                      NaN                   NaN                  NaN
# 4                      NaN                   NaN                  NaN
# 5                      NaN                   NaN                  NaN
# 6                      NaN                   NaN                  NaN
# 7                      NaN                   NaN                  NaN
# 8                      NaN                   NaN                  NaN
# 9                      NaN                   NaN                  NaN
# 10                     NaN                   NaN                  NaN
#
#     ca_product_account_limit  ca_product_depth_mm  ca_product_diameter_mm  \
# 0                        NaN                  NaN                     NaN
# 1                        NaN                  NaN                     NaN
# 2                        NaN                  NaN                     NaN
# 3                        NaN                  NaN                     NaN
# 4                        NaN                  NaN                     NaN
# 5                        NaN                  NaN                     NaN
# 6                        NaN                  NaN                     NaN
# 7                        NaN                  NaN                     NaN
# 8                        NaN                  NaN                     NaN
# 9                        NaN                  NaN                     NaN
# 10                       NaN                  NaN                     NaN
#
#     ca_product_effective_length_mm  ca_product_height_mm  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# 5                              NaN                   NaN
# 6                              NaN                   NaN
# 7                              NaN                   NaN
# 8                              NaN                   NaN
# 9                              NaN                   NaN
# 10                             NaN                   NaN
#
#     ca_product_inside_depth_mm  ca_product_inside_length_mm  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
# 10                         NaN                          NaN
#
#     ca_product_inside_width_mm  ca_product_width_mm  ca_products_inner_pack  \
# 0                          NaN                  NaN                     NaN
# 1                          NaN                  NaN                     NaN
# 2                          NaN                  NaN                     NaN
# 3                          NaN                  NaN                     NaN
# 4                          NaN                  NaN                     NaN
# 5                          NaN                  NaN                     NaN
# 6                          NaN                  NaN                     NaN
# 7                          NaN                  NaN                     NaN
# 8                          NaN                  NaN                     NaN
# 9                          NaN                  NaN                     NaN
# 10                         NaN                  NaN                     NaN
#
#     ca_resizable  ca_straps_length  ca_straps_width  ca_usb_capacity  \
# 0            NaN               NaN              NaN              NaN
# 1            NaN               NaN              NaN              NaN
# 2            NaN               NaN              NaN              NaN
# 3            NaN               NaN              NaN              NaN
# 4            NaN               NaN              NaN              NaN
# 5            NaN               NaN              NaN              NaN
# 6            NaN               NaN              NaN              NaN
# 7            NaN               NaN              NaN              NaN
# 8            NaN               NaN              NaN              NaN
# 9            NaN               NaN              NaN              NaN
# 10           NaN               NaN              NaN              NaN
#
#     ca_watch_strap_length_mm  ca_watch_strap_width_mm  ca_watch_waterproof  \
# 0                        NaN                      NaN                  NaN
# 1                        NaN                      NaN                  NaN
# 2                        NaN                      NaN                  NaN
# 3                        NaN                      NaN                  NaN
# 4                        NaN                      NaN                  NaN
# 5                        NaN                      NaN                  NaN
# 6                        NaN                      NaN                  NaN
# 7                        NaN                      NaN                  NaN
# 8                        NaN                      NaN                  NaN
# 9                        NaN                      NaN                  NaN
# 10                       NaN                      NaN                  NaN
#
#     ZZNFMAT ZZPLMID extraction_date
# 0       NaN     NaN      15-03-2024
# 1       NaN     NaN      15-03-2024
# 2       NaN     NaN      15-03-2024
# 3       NaN     NaN      15-03-2024
# 4       NaN     NaN      15-03-2024
# 5       NaN     NaN      15-03-2024
# 6       NaN   P_470      15-03-2024
# 7       NaN     NaN      15-03-2024
# 8       NaN     NaN      15-03-2024
# 9       NaN     NaN      15-03-2024
# 10      NaN     NaN      15-03-2024
